# %% [markdown]
# # Running the pipeline
# Here, we will run the pipeline. You should have a `metadata.tsv` file now that looks like so (replace by `metadata_10x.tsv` if you ran the 10x workflow):

# %%
cat metadata.tsv
# Out:
# sample_name	technology	fastq_PE1_path	fastq_barcode_path	fastq_PE2_path
# BIO_ddseq_4	biorad	/lustre1/project/stg_00002/lcb/fderop/data/20230411_ATACflow_tutorial/PUMATAC_example_fastq/BIO_ddseq_4__R1.LIBDS.fastq.gz	/lustre1/project/stg_00002/lcb/fderop/data/20230411_ATACflow_tutorial/PUMATAC_example_fastq/BIO_ddseq_4__R1.LIBDS.fastq.gz	/lustre1/project/stg_00002/lcb/fderop/data/20230411_ATACflow_tutorial/PUMATAC_example_fastq/BIO_ddseq_4__R1.LIBDS.fastq.gz
# EPF_hydrop_1	hydrop_2x384	/lustre1/project/stg_00002/lcb/fderop/data/20230411_ATACflow_tutorial/PUMATAC_example_fastq/EPF_hydrop_1__R1.LIBDS.fastq.gz	/lustre1/project/stg_00002/lcb/fderop/data/20230411_ATACflow_tutorial/PUMATAC_example_fastq/EPF_hydrop_1__R1.LIBDS.fastq.gz	/lustre1/project/stg_00002/lcb/fderop/data/20230411_ATACflow_tutorial/PUMATAC_example_fastq/EPF_hydrop_1__R1.LIBDS.fastq.gz
# OHS_s3atac_1	s3atac_1	/lustre1/project/stg_00002/lcb/fderop/data/20230411_ATACflow_tutorial/PUMATAC_example_fastq/OHS_s3atac_1__R1.LIBDS.fastq.gz	/lustre1/project/stg_00002/lcb/fderop/data/20230411_ATACflow_tutorial/PUMATAC_example_fastq/OHS_s3atac_1__R1.LIBDS.fastq.gz	/lustre1/project/stg_00002/lcb/fderop/data/20230411_ATACflow_tutorial/PUMATAC_example_fastq/OHS_s3atac_1__R1.LIBDS.fastq.gz
# VIB_10xv2_1	atac_revcomp	/lustre1/project/stg_00002/lcb/fderop/data/20230411_ATACflow_tutorial/PUMATAC_example_fastq/VIB_10xv2_1__R1.LIBDS.fastq.gz	/lustre1/project/stg_00002/lcb/fderop/data/20230411_ATACflow_tutorial/PUMATAC_example_fastq/VIB_10xv2_1__R1.LIBDS.fastq.gz	/lustre1/project/stg_00002/lcb/fderop/data/20230411_ATACflow_tutorial/PUMATAC_example_fastq/VIB_10xv2_1__R1.LIBDS.fastq.gz

# %%
cat metadata_10x.tsv
# Out:
# sample_name	technology	fastq_PE1_path	fastq_barcode_path	fastq_PE2_path
# ASA__0201f1__20220902_MO-016-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S5_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S5_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S5_L001_R3_001.fastq.gz
# ASA__0201f1__20220902_MO-016-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S5_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S5_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S5_L002_R3_001.fastq.gz
# ASA__0201f1__20220902_MO-016-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S6_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S6_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S6_L001_R3_001.fastq.gz
# ASA__0201f1__20220902_MO-016-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S6_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S6_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S6_L002_R3_001.fastq.gz
# ASA__0201f1__20220902_MO-016-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S7_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S7_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S7_L001_R3_001.fastq.gz
# ASA__0201f1__20220902_MO-016-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S7_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S7_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S7_L002_R3_001.fastq.gz
# ASA__0201f1__20220902_MO-016-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S8_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S8_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S8_L001_R3_001.fastq.gz
# ASA__0201f1__20220902_MO-016-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S8_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S8_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__0201f1__20220902_MO-016-b-ATAC_S8_L002_R3_001.fastq.gz
# ASA__089fab__20220902_MO-016-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S10_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S10_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S10_L001_R3_001.fastq.gz
# ASA__089fab__20220902_MO-016-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S10_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S10_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S10_L002_R3_001.fastq.gz
# ASA__089fab__20220902_MO-016-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S11_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S11_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S11_L001_R3_001.fastq.gz
# ASA__089fab__20220902_MO-016-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S11_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S11_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S11_L002_R3_001.fastq.gz
# ASA__089fab__20220902_MO-016-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S12_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S12_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S12_L001_R3_001.fastq.gz
# ASA__089fab__20220902_MO-016-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S12_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S12_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S12_L002_R3_001.fastq.gz
# ASA__089fab__20220902_MO-016-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S1_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S1_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S1_L001_R3_001.fastq.gz
# ASA__089fab__20220902_MO-016-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S1_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S1_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S1_L002_R3_001.fastq.gz
# ASA__089fab__20220902_MO-016-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S2_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S2_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S2_L001_R3_001.fastq.gz
# ASA__089fab__20220902_MO-016-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S2_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S2_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S2_L002_R3_001.fastq.gz
# ASA__089fab__20220902_MO-016-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S3_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S3_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S3_L001_R3_001.fastq.gz
# ASA__089fab__20220902_MO-016-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S3_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S3_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S3_L002_R3_001.fastq.gz
# ASA__089fab__20220902_MO-016-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S4_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S4_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S4_L001_R3_001.fastq.gz
# ASA__089fab__20220902_MO-016-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S4_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S4_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S4_L002_R3_001.fastq.gz
# ASA__089fab__20220902_MO-016-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S9_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S9_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S9_L001_R3_001.fastq.gz
# ASA__089fab__20220902_MO-016-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S9_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S9_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__089fab__20220902_MO-016-c-ATAC_S9_L002_R3_001.fastq.gz
# ASA__09f884__20230315_MO-018-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S5_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S5_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S5_L001_R3_001.fastq.gz
# ASA__09f884__20230315_MO-018-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S5_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S5_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S5_L002_R3_001.fastq.gz
# ASA__09f884__20230315_MO-018-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S6_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S6_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S6_L001_R3_001.fastq.gz
# ASA__09f884__20230315_MO-018-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S6_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S6_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S6_L002_R3_001.fastq.gz
# ASA__09f884__20230315_MO-018-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S7_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S7_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S7_L001_R3_001.fastq.gz
# ASA__09f884__20230315_MO-018-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S7_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S7_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S7_L002_R3_001.fastq.gz
# ASA__09f884__20230315_MO-018-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S8_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S8_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S8_L001_R3_001.fastq.gz
# ASA__09f884__20230315_MO-018-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S8_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S8_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__09f884__20230315_MO-018-b-ATAC_S8_L002_R3_001.fastq.gz
# ASA__12bf4c__20230315_MO-018-h-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S29_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S29_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S29_L001_R3_001.fastq.gz
# ASA__12bf4c__20230315_MO-018-h-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S29_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S29_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S29_L002_R3_001.fastq.gz
# ASA__12bf4c__20230315_MO-018-h-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S30_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S30_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S30_L001_R3_001.fastq.gz
# ASA__12bf4c__20230315_MO-018-h-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S30_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S30_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S30_L002_R3_001.fastq.gz
# ASA__12bf4c__20230315_MO-018-h-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S31_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S31_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S31_L001_R3_001.fastq.gz
# ASA__12bf4c__20230315_MO-018-h-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S31_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S31_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S31_L002_R3_001.fastq.gz
# ASA__12bf4c__20230315_MO-018-h-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S32_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S32_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S32_L001_R3_001.fastq.gz
# ASA__12bf4c__20230315_MO-018-h-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S32_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S32_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__12bf4c__20230315_MO-018-h-ATAC_S32_L002_R3_001.fastq.gz
# ASA__1bde8b__20230315_MO-018-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S1_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S1_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S1_L001_R3_001.fastq.gz
# ASA__1bde8b__20230315_MO-018-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S1_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S1_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S1_L002_R3_001.fastq.gz
# ASA__1bde8b__20230315_MO-018-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S2_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S2_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S2_L001_R3_001.fastq.gz
# ASA__1bde8b__20230315_MO-018-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S2_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S2_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S2_L002_R3_001.fastq.gz
# ASA__1bde8b__20230315_MO-018-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S3_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S3_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S3_L001_R3_001.fastq.gz
# ASA__1bde8b__20230315_MO-018-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S3_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S3_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S3_L002_R3_001.fastq.gz
# ASA__1bde8b__20230315_MO-018-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S4_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S4_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S4_L001_R3_001.fastq.gz
# ASA__1bde8b__20230315_MO-018-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S4_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S4_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1bde8b__20230315_MO-018-a-ATAC_S4_L002_R3_001.fastq.gz
# ASA__1e598f__20230315_MO-018-d-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S13_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S13_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S13_L001_R3_001.fastq.gz
# ASA__1e598f__20230315_MO-018-d-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S13_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S13_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S13_L002_R3_001.fastq.gz
# ASA__1e598f__20230315_MO-018-d-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S14_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S14_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S14_L001_R3_001.fastq.gz
# ASA__1e598f__20230315_MO-018-d-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S14_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S14_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S14_L002_R3_001.fastq.gz
# ASA__1e598f__20230315_MO-018-d-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S15_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S15_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S15_L001_R3_001.fastq.gz
# ASA__1e598f__20230315_MO-018-d-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S15_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S15_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S15_L002_R3_001.fastq.gz
# ASA__1e598f__20230315_MO-018-d-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S16_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S16_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S16_L001_R3_001.fastq.gz
# ASA__1e598f__20230315_MO-018-d-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S16_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S16_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__1e598f__20230315_MO-018-d-ATAC_S16_L002_R3_001.fastq.gz
# ASA__2b6050__20220927_MO-017-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S10_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S10_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S10_L001_R3_001.fastq.gz
# ASA__2b6050__20220927_MO-017-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S10_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S10_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S10_L002_R3_001.fastq.gz
# ASA__2b6050__20220927_MO-017-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S11_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S11_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S11_L001_R3_001.fastq.gz
# ASA__2b6050__20220927_MO-017-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S11_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S11_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S11_L002_R3_001.fastq.gz
# ASA__2b6050__20220927_MO-017-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S12_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S12_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S12_L001_R3_001.fastq.gz
# ASA__2b6050__20220927_MO-017-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S12_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S12_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S12_L002_R3_001.fastq.gz
# ASA__2b6050__20220927_MO-017-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S21_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S21_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S21_L001_R3_001.fastq.gz
# ASA__2b6050__20220927_MO-017-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S21_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S21_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S21_L002_R3_001.fastq.gz
# ASA__2b6050__20220927_MO-017-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S22_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S22_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S22_L001_R3_001.fastq.gz
# ASA__2b6050__20220927_MO-017-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S22_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S22_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S22_L002_R3_001.fastq.gz
# ASA__2b6050__20220927_MO-017-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S23_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S23_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S23_L001_R3_001.fastq.gz
# ASA__2b6050__20220927_MO-017-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S23_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S23_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S23_L002_R3_001.fastq.gz
# ASA__2b6050__20220927_MO-017-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S24_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S24_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S24_L001_R3_001.fastq.gz
# ASA__2b6050__20220927_MO-017-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S24_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S24_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S24_L002_R3_001.fastq.gz
# ASA__2b6050__20220927_MO-017-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S9_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S9_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S9_L001_R3_001.fastq.gz
# ASA__2b6050__20220927_MO-017-b-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S9_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S9_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__2b6050__20220927_MO-017-b-ATAC_S9_L002_R3_001.fastq.gz
# ASA__2cb45a__20230315_MO-018-g-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S25_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S25_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S25_L001_R3_001.fastq.gz
# ASA__2cb45a__20230315_MO-018-g-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S25_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S25_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S25_L002_R3_001.fastq.gz
# ASA__2cb45a__20230315_MO-018-g-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S26_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S26_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S26_L001_R3_001.fastq.gz
# ASA__2cb45a__20230315_MO-018-g-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S26_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S26_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S26_L002_R3_001.fastq.gz
# ASA__2cb45a__20230315_MO-018-g-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S27_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S27_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S27_L001_R3_001.fastq.gz
# ASA__2cb45a__20230315_MO-018-g-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S27_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S27_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S27_L002_R3_001.fastq.gz
# ASA__2cb45a__20230315_MO-018-g-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S28_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S28_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S28_L001_R3_001.fastq.gz
# ASA__2cb45a__20230315_MO-018-g-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S28_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S28_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__2cb45a__20230315_MO-018-g-ATAC_S28_L002_R3_001.fastq.gz
# ASA__4a5f45__20220927_MO-017-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S17_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S17_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S17_L001_R3_001.fastq.gz
# ASA__4a5f45__20220927_MO-017-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S17_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S17_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S17_L002_R3_001.fastq.gz
# ASA__4a5f45__20220927_MO-017-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S18_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S18_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S18_L001_R3_001.fastq.gz
# ASA__4a5f45__20220927_MO-017-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S18_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S18_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S18_L002_R3_001.fastq.gz
# ASA__4a5f45__20220927_MO-017-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S19_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S19_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S19_L001_R3_001.fastq.gz
# ASA__4a5f45__20220927_MO-017-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S19_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S19_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S19_L002_R3_001.fastq.gz
# ASA__4a5f45__20220927_MO-017-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S20_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S20_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S20_L001_R3_001.fastq.gz
# ASA__4a5f45__20220927_MO-017-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S20_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S20_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S20_L002_R3_001.fastq.gz
# ASA__4a5f45__20220927_MO-017-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S5_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S5_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S5_L001_R3_001.fastq.gz
# ASA__4a5f45__20220927_MO-017-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S5_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S5_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S5_L002_R3_001.fastq.gz
# ASA__4a5f45__20220927_MO-017-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S6_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S6_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S6_L001_R3_001.fastq.gz
# ASA__4a5f45__20220927_MO-017-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S6_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S6_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S6_L002_R3_001.fastq.gz
# ASA__4a5f45__20220927_MO-017-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S7_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S7_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S7_L001_R3_001.fastq.gz
# ASA__4a5f45__20220927_MO-017-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S7_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S7_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S7_L002_R3_001.fastq.gz
# ASA__4a5f45__20220927_MO-017-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S8_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S8_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S8_L001_R3_001.fastq.gz
# ASA__4a5f45__20220927_MO-017-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S8_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S8_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__4a5f45__20220927_MO-017-a-ATAC_S8_L002_R3_001.fastq.gz
# ASA__57620c__20230315_MO-018-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S10_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S10_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S10_L001_R3_001.fastq.gz
# ASA__57620c__20230315_MO-018-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S10_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S10_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S10_L002_R3_001.fastq.gz
# ASA__57620c__20230315_MO-018-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S11_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S11_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S11_L001_R3_001.fastq.gz
# ASA__57620c__20230315_MO-018-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S11_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S11_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S11_L002_R3_001.fastq.gz
# ASA__57620c__20230315_MO-018-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S12_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S12_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S12_L001_R3_001.fastq.gz
# ASA__57620c__20230315_MO-018-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S12_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S12_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S12_L002_R3_001.fastq.gz
# ASA__57620c__20230315_MO-018-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S9_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S9_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S9_L001_R3_001.fastq.gz
# ASA__57620c__20230315_MO-018-c-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S9_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S9_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__57620c__20230315_MO-018-c-ATAC_S9_L002_R3_001.fastq.gz
# ASA__5d65d4__20220927_MO-017-f-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__5d65d4__20220927_MO-017-f-ATAC_S37_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__5d65d4__20220927_MO-017-f-ATAC_S37_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__5d65d4__20220927_MO-017-f-ATAC_S37_L001_R3_001.fastq.gz
# ...
# ASA__ab17e7__20220902_MO-016-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__ab17e7__20220902_MO-016-a-ATAC_S3_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__ab17e7__20220902_MO-016-a-ATAC_S3_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__ab17e7__20220902_MO-016-a-ATAC_S3_L002_R3_001.fastq.gz
# ASA__ab17e7__20220902_MO-016-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__ab17e7__20220902_MO-016-a-ATAC_S4_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__ab17e7__20220902_MO-016-a-ATAC_S4_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__ab17e7__20220902_MO-016-a-ATAC_S4_L001_R3_001.fastq.gz
# ASA__ab17e7__20220902_MO-016-a-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__ab17e7__20220902_MO-016-a-ATAC_S4_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__ab17e7__20220902_MO-016-a-ATAC_S4_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__ab17e7__20220902_MO-016-a-ATAC_S4_L002_R3_001.fastq.gz
# ASA__b6fa6d__20220927_MO-017-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S17_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S17_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S17_L001_R3_001.fastq.gz
# ASA__b6fa6d__20220927_MO-017-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S17_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S17_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S17_L002_R3_001.fastq.gz
# ASA__b6fa6d__20220927_MO-017-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S18_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S18_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S18_L001_R3_001.fastq.gz
# ASA__b6fa6d__20220927_MO-017-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S18_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S18_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S18_L002_R3_001.fastq.gz
# ASA__b6fa6d__20220927_MO-017-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S19_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S19_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S19_L001_R3_001.fastq.gz
# ASA__b6fa6d__20220927_MO-017-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S19_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S19_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S19_L002_R3_001.fastq.gz
# ASA__b6fa6d__20220927_MO-017-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S20_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S20_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S20_L001_R3_001.fastq.gz
# ASA__b6fa6d__20220927_MO-017-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S20_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S20_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221222/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S20_L002_R3_001.fastq.gz
# ASA__b6fa6d__20220927_MO-017-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S33_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S33_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S33_L001_R3_001.fastq.gz
# ASA__b6fa6d__20220927_MO-017-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S33_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S33_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S33_L002_R3_001.fastq.gz
# ASA__b6fa6d__20220927_MO-017-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S34_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S34_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S34_L001_R3_001.fastq.gz
# ASA__b6fa6d__20220927_MO-017-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S34_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S34_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S34_L002_R3_001.fastq.gz
# ASA__b6fa6d__20220927_MO-017-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S35_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S35_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S35_L001_R3_001.fastq.gz
# ASA__b6fa6d__20220927_MO-017-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S35_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S35_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S35_L002_R3_001.fastq.gz
# ASA__b6fa6d__20220927_MO-017-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S36_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S36_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S36_L001_R3_001.fastq.gz
# ASA__b6fa6d__20220927_MO-017-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S36_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S36_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__b6fa6d__20220927_MO-017-e-ATAC_S36_L002_R3_001.fastq.gz
# ASA__e27b63__20220902_MO-016-d-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S13_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S13_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S13_L001_R3_001.fastq.gz
# ASA__e27b63__20220902_MO-016-d-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S13_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S13_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S13_L002_R3_001.fastq.gz
# ASA__e27b63__20220902_MO-016-d-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S14_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S14_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S14_L001_R3_001.fastq.gz
# ASA__e27b63__20220902_MO-016-d-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S14_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S14_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S14_L002_R3_001.fastq.gz
# ASA__e27b63__20220902_MO-016-d-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S15_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S15_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S15_L001_R3_001.fastq.gz
# ASA__e27b63__20220902_MO-016-d-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S15_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S15_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S15_L002_R3_001.fastq.gz
# ASA__e27b63__20220902_MO-016-d-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S16_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S16_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S16_L001_R3_001.fastq.gz
# ASA__e27b63__20220902_MO-016-d-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S16_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S16_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20221004/Demultiplexed/ASA__e27b63__20220902_MO-016-d-ATAC_S16_L002_R3_001.fastq.gz
# ASA__ffd613__20230315_MO-018-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S17_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S17_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S17_L001_R3_001.fastq.gz
# ASA__ffd613__20230315_MO-018-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S17_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S17_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S17_L002_R3_001.fastq.gz
# ASA__ffd613__20230315_MO-018-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S18_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S18_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S18_L001_R3_001.fastq.gz
# ASA__ffd613__20230315_MO-018-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S18_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S18_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S18_L002_R3_001.fastq.gz
# ASA__ffd613__20230315_MO-018-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S19_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S19_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S19_L001_R3_001.fastq.gz
# ASA__ffd613__20230315_MO-018-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S19_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S19_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S19_L002_R3_001.fastq.gz
# ASA__ffd613__20230315_MO-018-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S20_L001_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S20_L001_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S20_L001_R3_001.fastq.gz
# ASA__ffd613__20230315_MO-018-e-ATAC	atac_revcomp	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S20_L002_R1_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S20_L002_R2_001.fastq.gz	/lustre1/project/stg_00002/lcb/ngs_runs/NextSeq2000_20230403/Demultiplexed/ASA__ffd613__20230315_MO-018-e-ATAC_S20_L002_R3_001.fastq.gz

# %% [markdown]
# ### 1. Generate a .config file
# The config file contains a number of variables and paths that are needed by the pipeline. `$NXF_WORK` is a temporary `work` directory, which will contain intermediate files used by the pipeline. The final output files will be written in a directory which we aribtrarily name `PUMATAC_tutorial_preprocessing_out`.

# %%
chmod 755 PUMATAC_dependencies/nextflow/nextflow-22.10.7-all

# %%
module load Java/17.0.2
NXF_WORK=./work
[ ! -d $NXF_WORK ] && mkdir $NXF_WORK
PUMATAC_dependencies/nextflow/nextflow-22.10.7-all config ./PUMATAC/main_atac.nf \
    -profile atac_preprocess_rapid,vsc \
    > atac_preprocess_rapid_template.config

# %%
pygmentize -g atac_preprocess_rapid_template.config
# Out:
# manifest {
#    name = 'vib-singlecell-nf/vsn-pipelines'
#    description = 'A repository of pipelines for single-cell data in Nextflow DSL2'
#    homePage = 'https://github.com/vib-singlecell-nf/vsn-pipelines'
#    version = '0.27.0'
#    mainScript = 'main.nf'
#    defaultBranch = 'master'
#    nextflowVersion = '!21.04.3'
# }
#
# params {
#    global {
#       project_name = '10x_PBMC'
#       outdir = 'out'
#    }
#    misc {
#       test {
#          enabled = false
#       }
#    }
#    utils {
#       container = 'vibsinglecellnf/utils:0.4.0'
#       file_converter {
#          off = 'h5ad'
#          tagCellWithSampleId = true
#          remove10xGEMWell = false
#          useFilteredMatrix = true
#          makeVarIndexUnique = false
#       }
#       publish {
#          compressionLevel = 6
#          annotateWithBatchVariableName = false
#          mode = 'copy'
#       }
#    }
#    atac_preprocess_tools {
#       mark_duplicates_method = 'MarkDuplicates'
#       adapter_trimming_method = 'Trim_Galore'
#    }
#    data {
#       atac_preprocess {
#          metadata = 'metadata.tsv'
#       }
#    }
#    tools {
#       singlecelltoolkit {
#          container = 'vibsinglecellnf/singlecelltoolkit:2022-04-15-16314db'
#          barcode_correction {
#             max_mismatches = 1
#             min_frac_bcs_to_find = 0.5
#             whitelist {
#                atac = 'PUMATAC_dependencies/whitelists/737K-cratac-v1.txt.gz'
#                atac_revcomp = 'PUMATAC_dependencies/whitelists/737K-cratac-v1.REVCOMP.txt.gz'
#                multiome = 'PUMATAC_dependencies/whitelists/737K-arc-v1.txt.gz'
#                multiome_revcomp = 'PUMATAC_dependencies/whitelists/737K-arc-v1.REVCOMP.txt.gz'
#                hydrop_2x384 = 'PUMATAC_dependencies/whitelists/hydrop_384x384.REVCOMP.txt.gz'
#                hydrop_3x96_short = 'PUMATAC_dependencies/whitelists/20230120_hydrop-atac_ligation_all_revcomp.txt.gz'
#                s3_atac_1 = 'PUMATAC_dependencies/whitelists/s3_atac_1.txt.gz'
#             }
#          }
#          barcode_10x_scatac_fastqs {
#             uncorrected_bc_tag = 'CR'
#             barcode_quality_tag = 'CY'
#          }
#       }
#       trimgalore {
#          container = 'vibsinglecellnf/trimgalore:0.6.6'
#          trim {
#             paired = 'true'
#          }
#       }
#       bwamaptools {
#          container = 'vibsinglecellnf/bwamaptools:bwa-mem2-2.2.1-zlibng-2.0.6'
#          bwa_fasta = 'PUMATAC_dependencies/genomes/hg38_bwamem2/genome.fa'
#          bwa_version = 'bwa-mem2'
#       }
#       samtools {
#          container = 'vibsinglecellnf/samtools:0.3-1.16.1'
#       }
#       barcard {
#          barcode_multiplet {
#             report_ipynb = '/src/barcard/bin/barcard_otsu_filtering.ipynb'
#          }
#       }
#    }
# }
#
# process {
#    executor = 'local'
#    cpus = 2
#    memory = '60 GB'
#    clusterOptions = '-A cluster_account'
#    withLabel:compute_resources__default {
#       time = '1h'
#    }
#    withLabel:compute_resources__sctk_barcode {
#       cpus = 2
#       memory = '20 GB'
#       maxForks = 8
#    }
#    withLabel:compute_resources__barcode_10x_scatac_fastq_5cpus {
#       cpus = 5
#       memory = '40 GB'
#       maxForks = 5
#    }
#    withLabel:compute_resources__trimgalore__trim_5cpus {
#       cpus = 5
#       memory = '20 GB'
#       maxForks = 5
#    }
#    withLabel:compute_resources__picard__merge_sam_files_and_sort {
#       cpus = 4
#       memory = '100 GB'
#       maxForks = 4
#    }
#    withLabel:compute_resources__picard__mark_duplicates_and_sort {
#       cpus = 8
#       memory = '100 GB'
#       maxForks = 4
#    }
#    withLabel:compute_resources__sinto__fragments {
#       cpus = 4
#       memory = '40 GB'
#       maxForks = 8
#    }
#    withLabel:compute_resources__sinto__sort_fragments {
#       cpus = 1
#       memory = '40 GB'
#       maxForks = 8
#    }
#    withLabel:compute_resources__bap_barcode_multiplet_pipeline_8cpus {
#       cpus = 8
#       memory = '80 GB'
#       maxForks = 3
#    }
#    withLabel:compute_resources__minimal {
#       cpus = 1
#       memory = '1 GB'
#    }
#    withLabel:compute_resources__mem {
#       cpus = 4
#       memory = '160 GB'
#    }
#    withLabel:compute_resources__cpu {
#       cpus = 20
#       memory = '80 GB'
#    }
#    withLabel:compute_resources__report {
#       maxForks = 2
#       cpus = 1
#       memory = '160 GB'
#    }
#    withLabel:compute_resources__24hqueue {
#       time = '24h'
#    }
#    withLabel:compute_resources__bwa_mem {
#       executor = 'local'
#       cpus = 6
#       memory = '60 GB'
#       time = '24h'
#       maxForks = 8
#    }
# }
#
# timeline {
#    enabled = true
#    file = 'out/nextflow_reports/execution_timeline.html'
# }
#
# report {
#    enabled = true
#    file = 'out/nextflow_reports/execution_report.html'
# }
#
# trace {
#    enabled = true
#    file = 'out/nextflow_reports/execution_trace.txt'
# }
#
# dag {
#    enabled = true
#    file = 'out/nextflow_reports/pipeline_dag.svg'
# }
#
# min {
#    enabled = false
# }
#
# vsc {
#    enabled = true
# }
#
# singularity {
#    enabled = true
#    autoMounts = true
#    runOptions = '--cleanenv -H $PWD -B /lustre1,/staging,/data,${VSC_SCRATCH},${VSC_SCRATCH}/tmp:/tmp,${HOME}/.nextflow/assets/'
#    cacheDir = '/staging/leuven/res_00001/software/vsn_containers/'
# }

# %% [markdown]
# ### 2. Edit the .config file
# Now, you must modify `atac_preprocess_rapid_template.config` to fit your use case. I recommend saving a new file named `atac_preprocess_rapid.config`.

# %% [markdown]
# Rename the project and the output directory, where the output files will be written:

# %%
params {
   global {
      project_name = 'PUMATAC_tutorial'
      outdir = 'PUMATAC_tutorial_preprocessing_out'
   }
}

# %% [markdown]
# Redirect variable `metadata` to our newly made `metadata.tsv` or `metadata_10x.tsv` file:

# %%
params {
   data {
      atac_preprocess {
         metadata = 'metadata.tsv'
        }
    }
}

# %% [markdown]
# Add correct whitelist for each technology called in `metadata.tsv`. For example, we included a technology named `atac`. We therefore add `atac = 'resources/whitelists/737K-cratac-v1.txt.gz'`. `atac` is not one of the 5 basic options (`standard`, `hydrop_3x96`, `hydrop_2x384`, `multiome` and `biorad`.), so the pipeline will treat it as a `standard` barcode correction case, but with a custom whitelist.
#
# `PUMATAC_dependencies` already contains whitelists for 10x and HyDrop. If you have a custom technique, such as `s3_atac`, you can add your own whitelist.

# %%
params {
   tools {
      singlecelltoolkit {
         container = 'vibsinglecellnf/singlecelltoolkit:2022-04-15-16314db'
         barcode_correction {
            max_mismatches = 1
            min_frac_bcs_to_find = 0.5
            whitelist {
                atac = 'PUMATAC_dependencies/whitelists/737K-cratac-v1.txt.gz'
                atac_revcomp = 'PUMATAC_dependencies/whitelists/737K-cratac-v1.REVCOMP.txt.gz'
                multiome = 'PUMATAC_dependencies/whitelists/737K-arc-v1.txt.gz'
                multiome_revcomp = 'PUMATAC_dependencies/whitelists/737K-arc-v1.REVCOMP.txt.gz'
                hydrop_2x384 = 'PUMATAC_dependencies/whitelists/hydrop_384x384.REVCOMP.txt.gz'
                s3_atac_1 = 'PUMATAC_dependencies/whitelists/s3_atac_1.txt.gz'
            }
         }
     }
 }

# %% [markdown]
# Change `bwa_fasta = '/path/to/bwa_index/hg38.fa'` to your genome of choice.

# %%
params {
    tools {
         bwamaptools {
         bwa_fasta = 'PUMATAC_dependencies/genomes/hg38_bwamem2/genome.fa'
        }
    }
}

# %% [markdown]
# Change the `withLabel:compute_resources__bwa_mem` parameters, e.g. change `executor` to `local` to run on current node, instead of submitting a job with the PBS system. You can also change the number of CPUs per sample (i.e. per line in the `metadata.tsv`) here. If the runtime of `bwa-mem2` exceeds the time defined here (24 hours), the pipeline will stop. You can thus increase this time limit if necessary.

# %%
process {
   withLabel:compute_resources__bwa_mem {
      executor = 'local'
      cpus = 20
      memory = '120 GB'
      time = '24h'
      maxForks = 2
   }
}

# %% [markdown]
# Edit the singularity run options to include all mounts in which files that you require or want to write are located:

# %%
runOptions = '--cleanenv -H $PWD -B /lustre1,/staging,/data,${VSC_SCRATCH},${VSC_SCRATCH}/tmp:/tmp,${HOME}/.nextflow/assets/'

# %% [markdown]
# Give an arbitrary location to the `cache` directory. I like to arbitrarily name this directory `vsn_cache`, in the `resources/` subdirectory. The cache directory is somewhat important, as it will contain all singularity containers, which can be easily executed. For example, if you want to re-run some of the tools that the pipeline calls, without re-running the entire pipeline, you can simply open the relevant singularity container, and call the tool from within the container.

# %%
cacheDir = 'PUMATAC_dependencies/cache'

# %% [markdown]
# That should be everything. Here is an example of a functional `.config`. I suggest you run a difftool (e.g. https://text-compare.com/) on this to compare this to your own `.config` if you run into problems:

# %%
pygmentize -g atac_preprocess_rapid.config
# Out:
# manifest {
#    name = 'vib-singlecell-nf/vsn-pipelines'
#    description = 'A repository of pipelines for single-cell data in Nextflow DSL2'
#    homePage = 'https://github.com/vib-singlecell-nf/vsn-pipelines'
#    version = '0.27.0'
#    mainScript = 'main.nf'
#    defaultBranch = 'master'
#    nextflowVersion = '!21.04.3'
# }
#
# params {
#    global {
#       project_name = 'ATACflow_tutorial'
#       outdir = 'ATACflow_tutorial_preprocessing_out'
#    }
#    misc {
#       test {
#          enabled = false
#       }
#    }
#    utils {
#       container = 'vibsinglecellnf/utils:0.4.0'
#       file_converter {
#          off = 'h5ad'
#          tagCellWithSampleId = true
#          remove10xGEMWell = false
#          useFilteredMatrix = true
#          makeVarIndexUnique = false
#       }
#       publish {
#          compressionLevel = 6
#          annotateWithBatchVariableName = false
#          mode = 'copy'
#       }
#    }
#    atac_preprocess_tools {
#       mark_duplicates_method = 'MarkDuplicates'
#       adapter_trimming_method = 'Trim_Galore'
#    }
#    data {
#       atac_preprocess {
#          metadata = 'metadata.tsv'
#       }
#    }
#    tools {
#       singlecelltoolkit {
#          container = 'vibsinglecellnf/singlecelltoolkit:2022-04-15-16314db'
#          barcode_correction {
#             max_mismatches = 1
#             min_frac_bcs_to_find = 0.5
#             whitelist {
#                 atac = 'PUMATAC_dependencies/whitelists/737K-cratac-v1.txt.gz'
#                 atac_revcomp = 'PUMATAC_dependencies/whitelists/737K-cratac-v1.REVCOMP.txt.gz'
#                 multiome = 'PUMATAC_dependencies/whitelists/737K-arc-v1.txt.gz'
#                 multiome_revcomp = 'PUMATAC_dependencies/whitelists/737K-arc-v1.REVCOMP.txt.gz'
#                 hydrop_2x384 = 'PUMATAC_dependencies/whitelists/hydrop_384x384.REVCOMP.txt.gz'
#                 s3atac_1 = 'PUMATAC_dependencies/whitelists/s3atac_1.whitelist.txt.gz'
#             }
#          }
#          barcode_10x_scatac_fastqs {
#             uncorrected_bc_tag = 'CR'
#             barcode_quality_tag = 'CY'
#          }
#       }
#       trimgalore {
#          container = 'vibsinglecellnf/trimgalore:0.6.6'
#          trim {
#             paired = 'true'
#          }
#       }
#       fastp {
#          container = 'vibsinglecellnf/fastp:0.20.0'
#          thread = 1
#          clean_and_fastqc {
#             length_required = 20
#             adapter_fasta = '/lustre1/project/stg_00002/lcb/fderop/data/20230411_ATACflow_tutorial/PUMATAC_dependencies/ATACflow/src/fastp/assets/fastp.adapters'
#          }
#       }
#       bwamaptools {
#          container = 'vibsinglecellnf/bwamaptools:bwa-mem2-2.2.1-zlibng-2.0.6'
#          bwa_fasta = 'PUMATAC_dependencies/genomes/hg38_bwamem2/genome.fa'
#          bwa_version = 'bwa-mem2'
#       }
#       gatk {
#          container = 'broadinstitute/gatk:4.2.0.0'
#          estimate_library_complexity {
#             barcode_tag = 'CB'
#          }
#       }
#       barcard {
#          barcode_multiplet {
#             report_ipynb = '/src/barcard/bin/barcard_otsu_filtering.ipynb'
#          }
#       }
#    }
# }
#
# process {
#    executor = 'local'
#    cpus = 2
#    memory = '60 GB'
#    clusterOptions = '-A cluster_account'
#    withLabel:compute_resources__default {
#       time = '1h'
#    }
#    withLabel:compute_resources__sctk_barcode {
#       cpus = 2
#       memory = '20 GB'
#       maxForks = 8
#    }
#    withLabel:compute_resources__barcode_10x_scatac_fastq_5cpus {
#       cpus = 5
#       memory = '40 GB'
#       maxForks = 5
#    }
#    withLabel:compute_resources__trimgalore__trim_5cpus {
#       cpus = 5
#       memory = '20 GB'
#       maxForks = 5
#    }
#    withLabel:compute_resources__picard__merge_sam_files_and_sort {
#       cpus = 4
#       memory = '100 GB'
#       maxForks = 4
#    }
#    withLabel:compute_resources__picard__mark_duplicates_and_sort {
#       cpus = 8
#       memory = '100 GB'
#       maxForks = 4
#    }
#    withLabel:compute_resources__sinto__fragments {
#       cpus = 4
#       memory = '40 GB'
#       maxForks = 8
#    }
#    withLabel:compute_resources__sinto__sort_fragments {
#       cpus = 1
#       memory = '40 GB'
#       maxForks = 8
#    }
#    withLabel:compute_resources__bap_barcode_multiplet_pipeline_8cpus {
#       cpus = 8
#       memory = '80 GB'
#       maxForks = 3
#    }
#    withLabel:compute_resources__minimal {
#       cpus = 1
#       memory = '1 GB'
#    }
#    withLabel:compute_resources__mem {
#       cpus = 4
#       memory = '160 GB'
#    }
#    withLabel:compute_resources__cpu {
#       cpus = 20
#       memory = '80 GB'
#    }
#    withLabel:compute_resources__report {
#       maxForks = 2
#       cpus = 1
#       memory = '160 GB'
#    }
#    withLabel:compute_resources__24hqueue {
#       time = '24h'
#    }
#    withLabel:compute_resources__bwa_mem {
#       executor = 'local'
#       cpus = 20
#       memory = '120 GB'
#       time = '24h'
#       maxForks = 2
#    }
# }
#
# timeline {
#    enabled = true
#    file = 'out/nextflow_reports/execution_timeline.html'
# }
#
# report {
#    enabled = true
#    file = 'out/nextflow_reports/execution_report.html'
# }
#
# trace {
#    enabled = true
#    file = 'out/nextflow_reports/execution_trace.txt'
# }
#
# dag {
#    enabled = true
#    file = 'out/nextflow_reports/pipeline_dag.svg'
# }
#
# min {
#    enabled = false
# }
#
# vsc {
#    enabled = true
# }
#
# singularity {
#    enabled = true
#    autoMounts = true
#    runOptions = '--cleanenv -H $PWD -B /lustre1,/staging,/data,${VSC_SCRATCH},${VSC_SCRATCH}/tmp:/tmp,${HOME}/.nextflow/assets/'
#    cacheDir = 'PUMATAC_dependencies/cache'
# }

# %% [markdown]
# ### 3. Run the pipeline
# We now call the right version of NextFlow to run our pipeline `main_atac.nf` on our `atac_preprocess_rapid.config`. I usually do this in a tmux session, or as a submitted job.

# %%
PUMATAC_dependencies/nextflow/nextflow-21.04.3-all -C atac_preprocess_rapid.config run PUMATAC/main_atac.nf -entry atac_preprocess_rapid

# %% [markdown]
# The output will look like so:

# %% [markdown]
# ```
# N E X T F L O W  ~  version 21.04.3                                                                                                                                                                                                          Launching `PUMATAC/main_atac.nf` [festering_easley] - revision: c18ea24e2f                                                                                                                                                                  executor >  local (35)                                                                                                                                                                                                                       [03/1df167] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:bc_correct_standard:SCTK__BARCODE_CORRECTION (2)                         [100%] 2 of 2 ✔                                                                                   executor >  local (35)                                                                                                                                                                                                                       [03/1df167] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:bc_correct_standard:SCTK__BARCODE_CORRECTION (2)                         [100%] 2 of 2 ✔                                                                                   executor >  local (35)                                                                                                                                                                                                                       [03/1df167] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:bc_correct_standard:SCTK__BARCODE_CORRECTION (2)                         [100%] 2 of 2 ✔                                                                                   executor >  local (51)                                                                                                                                                                                                                       [03/1df167] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:bc_correct_standard:SCTK__BARCODE_CORRECTION (2)                         [100%] 2 of 2 ✔                                                                                   [68/016dd5] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:bc_correct_standard:PUBLISH_BC_STATS (2)                                 [100%] 2 of 2 ✔                                                                                   [17/c1a9fc] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:bc_correct_standard:SCTK__BARCODE_10X_SCATAC_FASTQ (1)                   [100%] 2 of 2 ✔                                                                                   [-        ] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:SCTK__EXTRACT_HYDROP_ATAC_BARCODE_3x96                                   -                                                                                                 [-        ] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:bc_correct_hydrop_3x96:SCTK__BARCODE_CORRECTION                          -                                                                                                 [-        ] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:bc_correct_hydrop_3x96:PUBLISH_BC_STATS                                  -                                                                                                 [-        ] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:bc_correct_hydrop_3x96:SCTK__BARCODE_10X_SCATAC_FASTQ                    -                                                                                                 [a3/c8a3a3] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:SCTK__EXTRACT_HYDROP_ATAC_BARCODE_2x384 (1)                              [100%] 1 of 1, cached: 1 ✔                                                                        [17/7f7075] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:bc_correct_hydrop_2x384:SCTK__BARCODE_CORRECTION (1)                     [100%] 1 of 1 ✔                                                                                   [90/d88953] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:bc_correct_hydrop_2x384:PUBLISH_BC_STATS (1)                             [100%] 1 of 1 ✔                                                                                   [38/9b45b9] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:bc_correct_hydrop_2x384:SCTK__BARCODE_10X_SCATAC_FASTQ (1)               [100%] 1 of 1 ✔                                                                                   [e8/f70d41] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:bc_correct_biorad:SCTK__EXTRACT_AND_CORRECT_BIORAD_BARCODE (1)           [100%] 1 of 1, cached: 1 ✔                                                                        [73/069f44] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:bc_correct_biorad:PUBLISH_BR_BC_STATS (1)                                [100%] 1 of 1, cached: 1 ✔                                                                        [ba/727e0e] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:adapter_trimming:TRIMGALORE__TRIM (3)                                    [100%] 4 of 4, cached: 1 ✔                                                                        [53/e25895] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:adapter_trimming:PUBLISH_FASTQS_TRIMLOG_PE1 (4)                          [100%] 4 of 4, cached: 1 ✔                                                                        [7e/b3bbae] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:adapter_trimming:PUBLISH_FASTQS_TRIMLOG_PE2 (4)                          [100%] 4 of 4, cached: 1 ✔                                                                        [66/e06b36] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:mapping:BWA_MAPPING_PE:BWA_MEM_PE (4)                                    [100%] 4 of 4, cached: 1 ✔                                                                        [c2/40a212] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:mapping:BWA_MAPPING_PE:PUBLISH_BAM (4)                                   [100%] 4 of 4, cached: 1 ✔                                                                        [b0/24e40b] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:mapping:BWA_MAPPING_PE:PUBLISH_BAM_INDEX (4)                             [100%] 4 of 4, cached: 1 ✔                                                                        [e6/7a5bf4] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:mapping:BWA_MAPPING_PE:MAPPING_SUMMARY (4)                               [100%] 4 of 4, cached: 1 ✔                                                                        [99/3a3557] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:mapping:BWA_MAPPING_PE:PUBLISH_MAPPING_SUMMARY (4)                       [100%] 4 of 4, cached: 1 ✔                                                                        [-        ] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:mapping:PICARD__MERGE_SAM_FILES_AND_SORT                                 -                                                                                                 [0e/2213fe] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:mapping:BAM_TO_FRAGMENTS:BARCARD__CREATE_FRAGMENTS_FROM_BAM (4)          [100%] 4 of 4, cached: 1 ✔                                                                        [26/ba7d27] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:mapping:DETECT_BARCODE_MULTIPLETS:BARCARD__DETECT_BARCODE_MULTIPLETS (4) [100%] 4 of 4, cached: 1 ✔                                                                        [4b/4b05bd] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:mapping:DETECT_BARCODE_MULTIPLETS:GENERATE_REPORT (4)                    [100%] 4 of 4, cached: 1 ✔                                                                        [5d/9aa30c] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:mapping:DETECT_BARCODE_MULTIPLETS:REPORT_TO_HTML (4)                     [100%] 4 of 4, cached: 1 ✔                                                                        [4f/0355ac] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:mapping:PUBLISH_FRAGMENTS (4)                                            [100%] 4 of 4, cached: 1 ✔                                                                        [78/2a227d] process > atac_preprocess_rapid:ATAC_PREPROCESS_RAPID:mapping:PUBLISH_FRAGMENTS_INDEX (4)                                      [100%] 4 of 4, cached: 1 ✔                                                                        Completed at: 19-Apr-2023 14:12:58                                                                                                                                                                                                           Duration    : 2h 45m 24s                                                                                                                                                                                                                     CPU hours   : 59.7 (21.3% cached)                                                                                                                                                                                                            Succeeded   : 51                                                                                                                                                                                                                             Cached      : 17
# ```
